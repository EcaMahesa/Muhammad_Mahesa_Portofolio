# %% [markdown]
# # Folium
#
# Visualisasi Geografis

# %%
# pip install folium

# %%
import numpy as np 
import pandas as pd 
import folium

# %% [markdown]
# ## Peta Dunia

# %%
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e01d0b4aec86fae81f5bee42d924384 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e01d0b4aec86fae81f5bee42d924384&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e01d0b4aec86fae81f5bee42d924384 = L.map(
#                 &quot;map_0e01d0b4aec86fae81f5bee42d924384&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b06c381f16ad315c637ac4f3062ecf82 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e01d0b4aec86fae81f5bee42d924384);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Peta Batam

# %%
batam_map = folium.Map(location=[1.054507, 	104.004120], zoom_start=12)
batam_map

# location: [latitude, longitude] --> dalam betuk decimal
# latitude pada southern hemisphere pakai tanda negatif (-)
# tiles: defaultnya street map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02a1502496d144d2e358e585d91b52b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02a1502496d144d2e358e585d91b52b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02a1502496d144d2e358e585d91b52b8 = L.map(
#                 &quot;map_02a1502496d144d2e358e585d91b52b8&quot;,
#                 {
#                     center: [1.054507, 104.00412],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_081453d843e5a57ccdc182ce63b4c1f6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_02a1502496d144d2e358e585d91b52b8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Peta Surabaya
#
# Menampilkan wilayah perairan

# %%
# ?folium.Map

# %%
folium.Map(location=[-7.250445, 112.768845], zoom_start=12, tiles='Stamen Toner')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9abf09fae92d895b0291d8078e90bd01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9abf09fae92d895b0291d8078e90bd01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9abf09fae92d895b0291d8078e90bd01 = L.map(
#                 &quot;map_9abf09fae92d895b0291d8078e90bd01&quot;,
#                 {
#                     center: [-7.250445, 112.768845],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c2dd3bd6357db63e191a38234e6c077 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9abf09fae92d895b0291d8078e90bd01);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Peta Bandung
#
# Menampilkan elevasi

# %%
folium.Map(location=[-6.914744, 107.609810], zoom_start=12, tiles='Stamen Terrain')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ade8f02f5f1d45bf1810af39db3a70f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ade8f02f5f1d45bf1810af39db3a70f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ade8f02f5f1d45bf1810af39db3a70f = L.map(
#                 &quot;map_2ade8f02f5f1d45bf1810af39db3a70f&quot;,
#                 {
#                     center: [-6.914744, 107.60981],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_672b2008f4973c53ac2350d75134fd25 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ade8f02f5f1d45bf1810af39db3a70f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Marker

# %%
# buat peta jakarta
jakarta_map = folium.Map(location=[-6.200000, 106.816666], zoom_start=12)

# buat marker Monas
monas_pin = folium.Marker(
    location=[-6.176132, 106.822864],
    tooltip= 'Monumen Nasional',        # label ketika dihover
    popup= 'Monas',                     # label ketika diklik
    icon= folium.Icon(
        color='red', 
        icon='home'
    )
)

# buat CircleMarker Ancol
ancol_area = folium.CircleMarker(
    location=[-6.128847, 106.833053],
    tooltip= 'Ancol',
    popup= 'Area rawan banjir',
    radius= 30,
    color='blue'
)

# memasukkan marker ke dalam peta
monas_pin.add_to(jakarta_map)
ancol_area.add_to(jakarta_map)

# menampilkan jakarta map
jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e737f248c8ac9fc8363c863e6ec398c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e737f248c8ac9fc8363c863e6ec398c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e737f248c8ac9fc8363c863e6ec398c0 = L.map(
#                 &quot;map_e737f248c8ac9fc8363c863e6ec398c0&quot;,
#                 {
#                     center: [-6.2, 106.816666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81d9693541927a5ccfeb67ff7507e044 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e737f248c8ac9fc8363c863e6ec398c0);
#
#
#             var marker_4ab838ab92c3a27c3fb0caca82af5637 = L.marker(
#                 [-6.176132, 106.822864],
#                 {}
#             ).addTo(map_e737f248c8ac9fc8363c863e6ec398c0);
#
#
#             var icon_b160f5d64432398e0fceec40a09ba6be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ab838ab92c3a27c3fb0caca82af5637.setIcon(icon_b160f5d64432398e0fceec40a09ba6be);
#
#
#         var popup_39e9ebe94a2d7a08c155a1bc0216d1b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef7300ed5de05bb204c7b5398db2529d = $(`&lt;div id=&quot;html_ef7300ed5de05bb204c7b5398db2529d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Monas&lt;/div&gt;`)[0];
#                 popup_39e9ebe94a2d7a08c155a1bc0216d1b7.setContent(html_ef7300ed5de05bb204c7b5398db2529d);
#
#
#
#         marker_4ab838ab92c3a27c3fb0caca82af5637.bindPopup(popup_39e9ebe94a2d7a08c155a1bc0216d1b7)
#         ;
#
#
#
#
#             marker_4ab838ab92c3a27c3fb0caca82af5637.bindTooltip(
#                 `&lt;div&gt;
#                      Monumen Nasional
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f834980fac80ead92d5f7eefca5b255e = L.circleMarker(
#                 [-6.128847, 106.833053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e737f248c8ac9fc8363c863e6ec398c0);
#
#
#         var popup_82159145584ca941b7357becea342de6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2c7e683b1373b1ea1700c2705e78091 = $(`&lt;div id=&quot;html_c2c7e683b1373b1ea1700c2705e78091&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area rawan banjir&lt;/div&gt;`)[0];
#                 popup_82159145584ca941b7357becea342de6.setContent(html_c2c7e683b1373b1ea1700c2705e78091);
#
#
#
#         circle_marker_f834980fac80ead92d5f7eefca5b255e.bindPopup(popup_82159145584ca941b7357becea342de6)
#         ;
#
#
#
#
#             circle_marker_f834980fac80ead92d5f7eefca5b255e.bindTooltip(
#                 `&lt;div&gt;
#                      Ancol
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Choropleth
#
# Data Source:
# * Jakarta Open Data, https://data.jakarta.go.id/dataset/pelaporan-perpindahan-penduduk-keluar-provinsi-dki-jakarta-tahun-2020-berdasarkan-kelurahan/resource/134253ff-2915-44b8-a1b3-2b1869366ed0
# * Jakarta by Kelurahan geo public, https://pstyd.carto.com/tables/jakarta_by_kelurahan_geo/public

# %%
df = pd.read_csv('pendatang_DKI_Maret_2020.csv')
df.head()
# Out:
#    tahun  bulan         kota_kabupaten                 kecamatan  \
# 0   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            kelurahan jenis_kelamin   jumlah
# 0     PULAU PANGGANG      Laki-Laki     0.0
# 1       PULAU KELAPA      Laki-Laki     2.0
# 2      PULAU HARAPAN      Laki-Laki     1.0
# 3  PULAU UNTUNG JAWA      Laki-Laki     3.0
# 4       PULAU TIDUNG      Laki-Laki     3.0

# %%
# totalkan jumlah pendatang tiap kelurahan
df = df.groupby('kelurahan').sum()[['jumlah']].reset_index()
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4292\2681890410.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby('kelurahan').sum()[['jumlah']].reset_index()
#              kelurahan  jumlah
# 0                ANCOL    17.0
# 1                ANGKE    22.0
# 2          BALEKAMBANG    30.0
# 3          BALI MESTER     4.0
# 4           BAMBU APUS    26.0
# ..                 ...     ...
# 262  UTAN KAYU SELATAN    30.0
# 263    UTAN KAYU UTARA    25.0
# 264       UTAN PANJANG    13.0
# 265            WARAKAS    22.0
# 266      WIJAYA KUSUMA    31.0
#
# [267 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   kelurahan  267 non-null    object
#  1   jumlah     267 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.3+ KB

# %%
# missing value diisi dengan nilai 0
df['jumlah'] = df['jumlah'].fillna(value=0)
df.isna().sum()
# Out:
# kelurahan    0
# jumlah       0
# dtype: int64

# %%
# buat peta jakarta
jakarta_map = folium.Map(location=[-6.200000, 106.816666], zoom_start=12)

# file geojson jakarta (untuk membuat batas kelurahan)
jakarta_geojson = r'jakarta_by_kelurahan_geo.geojson'

# Choropleth
chor_kelurahan = folium.Choropleth(
    geo_data= jakarta_geojson,          # file geojson (data geospatial)
    data= df,                           # dataframe pandas
    columns= ['kelurahan', 'jumlah'],   # kolom dataframe yg dipakai
    key_on= 'feature.properties.name'   # indexing nama kelurahan dlm file geojson untuk join dengan dataframe pandas
)

# Masukkan choropleth ke dalam peta jakarta
chor_kelurahan.add_to(jakarta_map)

jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_740b0f8afdf3b04003611feabb75882c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_740b0f8afdf3b04003611feabb75882c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_740b0f8afdf3b04003611feabb75882c = L.map(
#                 &quot;map_740b0f8afdf3b04003611feabb75882c&quot;,
#                 {
#                     center: [-6.2, 106.816666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e125f7d9c309558caf0f507828b7ca1a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_740b0f8afdf3b04003611feabb75882c);
#
#
#             var choropleth_741ae8a9e06c6f707238a5a6662df2f1 = L.featureGroup(
#                 {}
#             ).addTo(map_740b0f8afdf3b04003611feabb75882c);
#
#
#         function geo_json_d063b7283ab5f85b072762b642821dca_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;PASEBAN&quot;: case &quot;DUREN SAWIT&quot;: case &quot;KEBON BAWANG&quot;: case &quot;BATU AMPAR&quot;: case &quot;CEMPAKA BARU&quot;: case &quot;BIDARA CINA&quot;: case &quot;BAMBU APUS&quot;: case &quot;BARU&quot;: case &quot;BINTARO&quot;: case &quot;CAWANG&quot;: case &quot;CEMPAKA PUTIH BARAT&quot;: case &quot;CIGANJUR&quot;: case &quot;CIJANTUNG&quot;: case &quot;CILANDAK BARAT&quot;: case &quot;CILANDAK TIMUR&quot;: case &quot;DUREN TIGA&quot;: case &quot;CILANGKAP&quot;: case &quot;CILILITAN&quot;: case &quot;CILINCING&quot;: case &quot;CIPETE UTARA&quot;: case &quot;CIPINANG&quot;: case &quot;CIPINANG BESAR SELATAN&quot;: case &quot;CIPINANG BESAR UTARA&quot;: case &quot;DURI KEPA&quot;: case &quot;GANDARIA UTARA&quot;: case &quot;GEDONG&quot;: case &quot;GROGOL UTARA&quot;: case &quot;GUNUNG SAHARI SELATAN&quot;: case &quot;JAGAKARSA&quot;: case &quot;JELAMBAR BARU&quot;: case &quot;JEMBATAN BESI&quot;: case &quot;JOHAR BARU&quot;: case &quot;KALI ANYAR&quot;: case &quot;KALIBATA&quot;: case &quot;KALISARI&quot;: case &quot;KAMAL MUARA&quot;: case &quot;KAMPUNG MELAYU&quot;: case &quot;KEDAUNG KALI ANGKE&quot;: case &quot;KAYU PUTIH&quot;: case &quot;KEBAYORAN LAMA SELATAN&quot;: case &quot;KEBAYORAN LAMA UTARA&quot;: case &quot;KEBON PALA&quot;: case &quot;KEDOYA UTARA&quot;: case &quot;KELAPA GADING BARAT&quot;: case &quot;LAGOA&quot;: case &quot;KEMBANGAN UTARA&quot;: case &quot;KOJA&quot;: case &quot;LUBANG BUAYA&quot;: case &quot;MAKASAR&quot;: case &quot;SERDANG&quot;: case &quot;MANGGA DUA SELATAN&quot;: case &quot;MARUNDA&quot;: case &quot;MERUYA SELATAN&quot;: case &quot;MERUYA UTARA&quot;: case &quot;PAPANGGO&quot;: case &quot;PEGANGSAAN DUA&quot;: case &quot;PEJATEN TIMUR&quot;: case &quot;PEKAYON&quot;: case &quot;PESANGGRAHAN&quot;: case &quot;PETUKANGAN SELATAN&quot;: case &quot;PISANGAN BARU&quot;: case &quot;PISANGAN TIMUR&quot;: case &quot;RAWAJATI&quot;: case &quot;PLUIT&quot;: case &quot;PONDOK KOPI&quot;: case &quot;PONDOK PINANG&quot;: case &quot;SUSUKAN&quot;: case &quot;RAWA BADAK SELATAN&quot;: case &quot;RAWA BADAK UTARA&quot;: case &quot;RAWAMANGUN&quot;: case &quot;ROROTAN&quot;: case &quot;SEMPER TIMUR&quot;: case &quot;TANAH TINGGI&quot;: case &quot;SRENGSENG&quot;: case &quot;SUKABUMI SELATAN&quot;: case &quot;SUKABUMI UTARA&quot;: case &quot;SUNGAI BAMBU&quot;: case &quot;SUNTER JAYA&quot;: case &quot;TANJUNG PRIOK&quot;: case &quot;TUGU UTARA&quot;: case &quot;UJUNG MENTENG&quot;: case &quot;ULUJAMI&quot;: case &quot;UTAN KAYU SELATAN&quot;: case &quot;UTAN KAYU UTARA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;SETIABUDI&quot;: case &quot;BALE KAMBANG&quot;: case &quot;JATI PULO&quot;: case &quot;JATIPADANG&quot;: case &quot;HALIM PERDANA KUSUMA&quot;: case &quot;KAMPUNG TENGAH&quot;: case &quot;KRAMAT JATI&quot;: case &quot;PAL MERIAM&quot;: case &quot;PINANG RANTI&quot;: case &quot;PONDOK RANGON&quot;: case &quot;PULOGADUNG&quot;: case &quot;TMII&quot;: case &quot;WIJAYA KESUMA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CAKUNG BARAT&quot;: case &quot;CAKUNG TIMUR&quot;: case &quot;CENGKARENG BARAT&quot;: case &quot;CIBUBUR&quot;: case &quot;CIRACAS&quot;: case &quot;JOGLO&quot;: case &quot;KALIBARU&quot;: case &quot;KAMAL&quot;: case &quot;KEBON JERUK&quot;: case &quot;KEBON KOSONG&quot;: case &quot

# %%
df[df['kelurahan'].str.contains('SETIA BUDI')]

# wilayah yg berwarna hitam karena datanya ada di geojson tapi tidak ada di dataframe pandas atau sebaliknya
# contoh: di geojson tertulis 'SETIABUDI' tapi di dataframe pandas tertulis 'SETIA BUDI'
# Out:
#       kelurahan  jumlah
# 230  SETIA BUDI     3.0

# %%
df[df['kelurahan'].str.contains('JATIPULO')]
# Out:
#    kelurahan  jumlah
# 75  JATIPULO    33.0

# %%
# Ubah nama kelurahan di dataframe pandas dari 'SETIA BUDI' menjadi 'SETIABUDI' agar sama dengan nama di geojson
df['kelurahan'] = df['kelurahan'].replace('SETIA BUDI', 'SETIABUDI')

# %%
# cek apakah sudah terubah
df[df['kelurahan'].str.contains('SETIABUDI')]
# Out:
#      kelurahan  jumlah
# 230  SETIABUDI     3.0

# %%
# bins untuk legend
bins_jumlah = df['jumlah'].quantile([0, 0.25, 0.50, 0.75, 1])
bins_jumlah
# Out:
# 0.00      0.0
# 0.25     13.0
# 0.50     24.0
# 0.75     36.0
# 1.00    145.0
# Name: jumlah, dtype: float64

# %%
len(df)/4
# Out:
# 66.75

# %%
# Setelah ada 'SETIABUDI' 

# buat peta jakarta
jakarta_map = folium.Map(location=[-6.200000, 106.816666], zoom_start=12)

# file geojson jakarta (untuk membuat batas kelurahan)
jakarta_geojson = r'jakarta_by_kelurahan_geo.geojson'

# Choropleth
chor_kelurahan = folium.Choropleth(
    geo_data= jakarta_geojson,          # file geojson (data geospatial)
    data= df,                           # dataframe pandas
    columns= ['kelurahan', 'jumlah'],   # kolom dataframe yg dipakai
    key_on= 'feature.properties.name',  # indexing nama kelurahan dlm file geojson untuk join dengan dataframe pandas
    fill_color= 'YlOrRd',
    fill_opacity= 0.7,
    line_opacity= 0.2,
    bins= bins_jumlah                   # bins untuk legend
)

# Masukkan choropleth ke dalam peta jakarta
chor_kelurahan.add_to(jakarta_map)

jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_959d4fba621d6ca74362f99747e7bac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_959d4fba621d6ca74362f99747e7bac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_959d4fba621d6ca74362f99747e7bac8 = L.map(
#                 &quot;map_959d4fba621d6ca74362f99747e7bac8&quot;,
#                 {
#                     center: [-6.2, 106.816666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63709657aaa2758890fb7e3bf8f87a33 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_959d4fba621d6ca74362f99747e7bac8);
#
#
#             var choropleth_8cf663083f9ff984be2ef1aef31c445e = L.featureGroup(
#                 {}
#             ).addTo(map_959d4fba621d6ca74362f99747e7bac8);
#
#
#         function geo_json_2d9bbb81a21b085ce20865454cc8bd93_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;ANGKE&quot;: case &quot;KRENDANG&quot;: case &quot;PETOJO UTARA&quot;: case &quot;ANCOL&quot;: case &quot;BUKIT DURI&quot;: case &quot;CEGER&quot;: case &quot;CEMPAKA PUTIH TIMUR&quot;: case &quot;GALUR&quot;: case &quot;MANGGARAI SELATAN&quot;: case &quot;CIPAYUNG&quot;: case &quot;CIPEDAK&quot;: case &quot;CIPETE SELATAN&quot;: case &quot;CIPINANG CEMPEDAK&quot;: case &quot;CIPINANG MUARA&quot;: case &quot;CIPULIR&quot;: case &quot;DUKUH&quot;: case &quot;DURI PULO&quot;: case &quot;DURI UTARA&quot;: case &quot;GANDARIA SELATAN&quot;: case &quot;GROGOL&quot;: case &quot;GROGOL SELATAN&quot;: case &quot;HARAPAN MULIA&quot;: case &quot;JATI&quot;: case &quot;JATINEGARA KAUM&quot;: case &quot;JELAMBAR&quot;: case &quot;JEMBATAN LIMA&quot;: case &quot;KAPUK MUARA&quot;: case &quot;KARANG ANYAR&quot;: case &quot;KARET TENGSIN&quot;: case &quot;KAYU MANIS&quot;: case &quot;KEBAGUSAN&quot;: case &quot;KEBON KACANG&quot;: case &quot;KEBON KELAPA&quot;: case &quot;KEBON SIRIH&quot;: case &quot;KWITANG&quot;: case &quot;KEDOYA SELATAN&quot;: case &quot;KELAPA DUA&quot;: case &quot;KELAPA GADING TIMUR&quot;: case &quot;KEMAYORAN&quot;: case &quot;KEMBANGAN SELATAN&quot;: case &quot;KENARI&quot;: case &quot;KOTA BAMBU UTARA&quot;: case &quot;KRAMAT PELA&quot;: case &quot;LEBAK BULUS&quot;: case &quot;MALAKA JAYA&quot;: case &quot;MALAKA SARI&quot;: case &quot;MAPHAR&quot;: case &quot;MENTENG&quot;: case &quot;MUNJUL&quot;: case &quot;PASAR MANGGIS&quot;: case &quot;PASAR MINGGU&quot;: case &quot;PEGANGSAAN&quot;: case &quot;PEJATEN BARAT&quot;: case &quot;PEKOJAN&quot;: case &quot;PELA MAMPANG&quot;: case &quot;PETAMBURAN&quot;: case &quot;PETOJO SELATAN&quot;: case &quot;RAWA BUNGA&quot;: case &quot;RAWA TERATE&quot;: case &quot;RAWASARI&quot;: case &quot;SETU&quot;: case &quot;SUMUR BATU&quot;: case &quot;TANJUNG BARAT&quot;: case &quot;TEGAL PARANG&quot;: case &quot;UTAN PANJANG&quot;: case &quot;WARAKAS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;PASEBAN&quot;: case &quot;DUREN SAWIT&quot;: case &quot;BAMBU APUS&quot;: case &quot;BARU&quot;: case &quot;BINTARO&quot;: case &quot;CAWANG&quot;: case &quot;CEMPAKA PUTIH BARAT&quot;: case &quot;CILANDAK TIMUR&quot;: case &quot;DUREN TIGA&quot;: case &quot;CILANGKAP&quot;: case &quot;CILINCING&quot;: case &quot;CIPETE UTARA&quot;: case &quot;CIPINANG&quot;: case &quot;CIPINANG BESAR SELATAN&quot;: case &quot;CIPINANG BESAR UTARA&quot;: case &quot;DURI KEPA&quot;: case &quot;GANDARIA UTARA&quot;: case &quot;GEDONG&quot;: case &quot;GROGOL UTARA&quot;: case &quot;GUNUNG SAHARI SELATAN&quot;: case &quot;JELAMBAR BARU&quot;: case &quot;JEMBATAN BESI&quot;: case &quot;JOHAR BARU&quot;: case &quot;KALI ANYAR&quot;: case &quot;KALISARI&quot;: case &quot;KAMAL MUARA&quot;: case &quot;KAMPUNG MELAYU&quot;: case &quot;KEDAUNG KALI ANGKE&quot;: case &quot;KAYU PUTIH&quot;: case &quot;KEBAYORAN LAMA SELATAN&quot;: case &quot;KEBAYORAN LAMA UTARA&quot;: case &quot;KEBON PALA&quot;: case &quot;KEDOYA UTARA&quot;: case &quot;LAGOA&quot;: case &quot;KOJA&quot;: case &quot;MAKASAR&quot;: case &quot;SERDANG&quot;: case &quot;MANGGA DUA SELATAN&quot;: case &quot;MARUNDA&quot;: case &quot;PALMERAH&quot;: case &quot;PAPANGGO&quot;: case &quot;PEJATEN TIMUR&quot;: case &quot;PISANGAN BARU&quot;: case &quot;PISANGAN TIMUR&quot;: case &quot;PONDOK KOPI&quot;: case &quot;PONDOK PINANG&quot;: case &quot;RAMBUTAN&quot;: case &quot;RAWA BADAK UTARA&quot;: case &quot;RAWAMANGUN&quot;: case &quot;SEMPER TIM

# %%
df[df['kelurahan'].str.contains('ANCOL')]
# Out:
#   kelurahan  jumlah
# 0     ANCOL    17.0

# %% [markdown]
# # Exercise

# %%
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## No.1
#
# - Tampilkan lokasi rumah paling mahal
# - Tandai dengan icon pin warna hitam
# - Beri tooltip berupa 'Rumah Termahal'
# - Beri popup berupa alamat/address

# %%
maksimal = df['Price'].max()

# %%
df[df['Price'] == maksimal]
# Out:
#          Suburb      Address  Rooms Type      Price Method SellerG  \
# 12094  Mulgrave  35 Bevis St      3    h  9000000.0     PI    Hall
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 12094  29/07/2017      18.8    3170.0  ...       1.0  1.0     744.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 12094         117.0     1960.0       Monash -37.93168   145.16126
#
#                        Regionname Propertycount
# 12094  South-Eastern Metropolitan        7113.0
#
# [1 rows x 21 columns]

# %%
# buat peta jakarta
melbourne_map = folium.Map(location=[-37.840935, 144.946457])

# buat marker Monas
maksimal_pin = folium.Marker(
    location=[-37.93168, 145.16126],
    tooltip= 'Rumah Termahal',        # label ketika dihover
    popup= '35 Bevis St',                     # label ketika diklik
    icon= folium.Icon(
        color='black', 
        icon='pin'
    )
)

maksimal_pin.add_to(melbourne_map)
melbourne_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc198c71a246dc4e7537d9bea8a0d0f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc198c71a246dc4e7537d9bea8a0d0f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc198c71a246dc4e7537d9bea8a0d0f4 = L.map(
#                 &quot;map_bc198c71a246dc4e7537d9bea8a0d0f4&quot;,
#                 {
#                     center: [-37.840935, 144.946457],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_295e6783cdb7618966458b7bb7a41a5d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bc198c71a246dc4e7537d9bea8a0d0f4);
#
#
#             var marker_411f7f4b39f9fad520b29af7c7a1f615 = L.marker(
#                 [-37.93168, 145.16126],
#                 {}
#             ).addTo(map_bc198c71a246dc4e7537d9bea8a0d0f4);
#
#
#             var icon_f943ad9691a57d348d6a3f4e22dddf33 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;pin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_411f7f4b39f9fad520b29af7c7a1f615.setIcon(icon_f943ad9691a57d348d6a3f4e22dddf33);
#
#
#         var popup_bca681481fb5104e657fa300c41b02ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e76e1671d342ef6ce12695ebe1b7c275 = $(`&lt;div id=&quot;html_e76e1671d342ef6ce12695ebe1b7c275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;35 Bevis St&lt;/div&gt;`)[0];
#                 popup_bca681481fb5104e657fa300c41b02ff.setContent(html_e76e1671d342ef6ce12695ebe1b7c275);
#
#
#
#         marker_411f7f4b39f9fad520b29af7c7a1f615.bindPopup(popup_bca681481fb5104e657fa300c41b02ff)
#         ;
#
#
#
#
#             marker_411f7f4b39f9fad520b29af7c7a1f615.bindTooltip(
#                 `&lt;div&gt;
#                      Rumah Termahal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## No.2
#
# - Ceritanya kita sedang mencari apartemen (type= 'u') dengan 2 kamar tidur (Bedroom2) dengan harga yg murah
# - Coba tampilkan peta kota melbourne
# - Berikan marker pada 5 apartemen dengan harga paling murah
# - Berikan tooltip berupa harga rumah
# - Berikan popup berupa Suburb dan Address-nya

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
df[(df['Type'] == 'u')&(df['Bedroom2']==2)]
# Out:
#                  Suburb              Address  Rooms Type     Price Method  \
# 10           Abbotsford   411/8 Grosvenor St      2    u  700000.0     VB
# 12           Abbotsford  123/56 Nicholson St      2    u  750000.0      S
# 23           Abbotsford   6/219 Nicholson St      2    u  500000.0      S
# 44         Airport West     2/49 McIntosh St      2    u  500000.0     VB
# 49         Airport West         3/19 Hart St      2    u  515000.0      S
# ...                 ...                  ...    ...  ...       ...    ...
# 13453  Hoppers Crossing      3/14 Moffatt Cr      2    u  315000.0      S
# 13482      Malvern East      2002 Malvern Rd      2    u  651000.0     SP
# 13495      Moonee Ponds      1/53 Buckley St      2    u  435000.0      S
# 13510        Nunawading        3/39 Lemon Gr      2    u  710000.0      S
# 13530         Reservoir           92 Pine St      2    u  625500.0      S
#
#        SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 10      Jellis  12/11/2016       2.5    3067.0  ...       2.0  1.0       0.0
# 12      Biggin  12/11/2016       2.5    3067.0  ...       2.0  1.0       0.0
# 23     Collins  18/06/2016       2.5    3067.0  ...       1.0  1.0       0.0
# 44       Barry   4/03/2017      13.5    3042.0  ...       1.0  1.0     168.0
# 49       Barry   7/11/2016      13.5    3042.0  ...       1.0  1.0     141.0
# ...        ...         ...       ...       ...  ...       ...  ...       ...
# 13453  Triwest  26/08/2017      18.4    3029.0  ...       1.0  1.0     150.0
# 13482   Jellis  26/08/2017       8.4    3145.0  ...       1.0  1.0     129.0
# 13495   Nelson  26/08/2017       6.2    3039.0  ...       1.0  1.0    1475.0
# 13510   Jellis  26/08/2017      15.4    3131.0  ...       1.0  1.0     903.0
# 13530       RW  26/08/2017      12.0    3073.0  ...       1.0  2.0     343.0
#
#        BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# 10              NaN        NaN          Yarra -37.81100   145.00670
# 12             94.0     2009.0          Yarra -37.80780   144.99650
# 23             60.0     1970.0          Yarra -37.80150   144.99720
# 44             86.0     2011.0  Moonee Valley -37.72150   144.88640
# 49             73.0     2013.0  Moonee Valley -37.72980   144.88830
# ...             ...        ...            ...       ...         ...
# 13453           NaN        NaN            NaN -37.87715   144.69863
# 13482          97.0     1940.0            NaN -37.87798   145.06731
# 13495          66.0     1970.0            NaN -37.75799   144.92354
# 13510           NaN     1985.0            NaN -37.80640   145.18452
# 13530         111.0     1960.0            NaN -37.71626   144.99866
#
#                   Regionname Propertycount
# 10     Northern Metropolitan        4019.0
# 12     Northern Metropolitan        4019.0
# 23     Northern Metropolitan        4019.0
# 44      Western Metropolitan        3464.0
# 49      Western Metropolitan        3464.0
# ...                      ...           ...
# 13453   Western Metropolitan       13830.0
# 13482  Southern Metropolitan        8801.0
# 13495   Western Metropolitan        6232.0
# 13510   Eastern Metropolitan        4973.0
# 13530  Northern Metropolitan       21650.0
#
# [1917 rows x 21 columns]

# %%
harga_rata = df[(df['Type'] == 'u')&(df['Bedroom2']==2)]['Price'].mean()

# %%
df_murah = df[(df['Type'] == 'u')&(df['Price'] < harga_rata)&(df['Bedroom2']==2)]
df_murah
# Out:
#                  Suburb              Address  Rooms Type     Price Method  \
# 23           Abbotsford   6/219 Nicholson St      2    u  500000.0      S
# 44         Airport West     2/49 McIntosh St      2    u  500000.0     VB
# 49         Airport West         3/19 Hart St      2    u  515000.0      S
# 50         Airport West   2/62 Clydesdale Rd      2    u  530000.0      S
# 54         Airport West      145a Victory Rd      2    u  440000.0      S
# ...                 ...                  ...    ...  ...       ...    ...
# 13129    Brunswick East       2/162 Lygon St      2    u  522000.0     SP
# 13179        Flemington  2/121 Wellington St      2    u  452500.0      S
# 13439     Greensborough      2/5 McDowell St      2    u  540000.0      S
# 13453  Hoppers Crossing      3/14 Moffatt Cr      2    u  315000.0      S
# 13495      Moonee Ponds      1/53 Buckley St      2    u  435000.0      S
#
#        SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 23     Collins  18/06/2016       2.5    3067.0  ...       1.0  1.0       0.0
# 44       Barry   4/03/2017      13.5    3042.0  ...       1.0  1.0     168.0
# 49       Barry   7/11/2016      13.5    3042.0  ...       1.0  1.0     141.0
# 50      Nelson  10/09/2016      13.5    3042.0  ...       1.0  1.0     120.0
# 54       Barry  13/08/2016      13.5    3042.0  ...       1.0  1.0     192.0
# ...        ...         ...       ...       ...  ...       ...  ...       ...
# 13129   Jellis  23/09/2017       4.0    3057.0  ...       1.0  1.0     186.0
# 13179   Nelson  23/09/2017       3.4    3031.0  ...       1.0  1.0     807.0
# 13439   Darren  26/08/2017      16.1    3088.0  ...       1.0  1.0     208.0
# 13453  Triwest  26/08/2017      18.4    3029.0  ...       1.0  1.0     150.0
# 13495   Nelson  26/08/2017       6.2    3039.0  ...       1.0  1.0    1475.0
#
#        BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# 23             60.0     1970.0          Yarra -37.80150   144.99720
# 44             86.0     2011.0  Moonee Valley -37.72150   144.88640
# 49             73.0     2013.0  Moonee Valley -37.72980   144.88830
# 50             94.0     2012.0  Moonee Valley -37.72340   144.87920
# 54              NaN        NaN  Moonee Valley -37.71770   144.87870
# ...             ...        ...            ...       ...         ...
# 13129           NaN        NaN            NaN -37.77315   144.97161
# 13179          54.0     1970.0            NaN -37.78300   144.93204
# 13439           NaN     1995.0            NaN -37.70791   145.09575
# 13453           NaN        NaN            NaN -37.87715   144.69863
# 13495          66.0     1970.0            NaN -37.75799   144.92354
#
#                   Regionname Propertycount
# 23     Northern Metropolitan        4019.0
# 44      Western Metropolitan        3464.0
# 49      Western Metropolitan        3464.0
# 50      Western Metropolitan        3464.0
# 54      Western Metropolitan        3464.0
# ...                      ...           ...
# 13129  Northern Metropolitan        5533.0
# 13179  Northern Metropolitan        3593.0
# 13439  Northern Metropolitan        8524.0
# 13453   Western Metropolitan       13830.0
# 13495   Western Metropolitan        6232.0
#
# [1087 rows x 21 columns]

# %%
melbourne_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc198c71a246dc4e7537d9bea8a0d0f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc198c71a246dc4e7537d9bea8a0d0f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc198c71a246dc4e7537d9bea8a0d0f4 = L.map(
#                 &quot;map_bc198c71a246dc4e7537d9bea8a0d0f4&quot;,
#                 {
#                     center: [-37.840935, 144.946457],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_295e6783cdb7618966458b7bb7a41a5d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bc198c71a246dc4e7537d9bea8a0d0f4);
#
#
#             var marker_411f7f4b39f9fad520b29af7c7a1f615 = L.marker(
#                 [-37.93168, 145.16126],
#                 {}
#             ).addTo(map_bc198c71a246dc4e7537d9bea8a0d0f4);
#
#
#             var icon_f943ad9691a57d348d6a3f4e22dddf33 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;pin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_411f7f4b39f9fad520b29af7c7a1f615.setIcon(icon_f943ad9691a57d348d6a3f4e22dddf33);
#
#
#         var popup_bca681481fb5104e657fa300c41b02ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e76e1671d342ef6ce12695ebe1b7c275 = $(`&lt;div id=&quot;html_e76e1671d342ef6ce12695ebe1b7c275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;35 Bevis St&lt;/div&gt;`)[0];
#                 popup_bca681481fb5104e657fa300c41b02ff.setContent(html_e76e1671d342ef6ce12695ebe1b7c275);
#
#
#
#         marker_411f7f4b39f9fad520b29af7c7a1f615.bindPopup(popup_bca681481fb5104e657fa300c41b02ff)
#         ;
#
#
#
#
#             marker_411f7f4b39f9fad520b29af7c7a1f615.bindTooltip(
#                 `&lt;div&gt;
#                      Rumah Termahal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_murah
# Out:
#                  Suburb              Address  Rooms Type     Price Method  \
# 23           Abbotsford   6/219 Nicholson St      2    u  500000.0      S
# 44         Airport West     2/49 McIntosh St      2    u  500000.0     VB
# 49         Airport West         3/19 Hart St      2    u  515000.0      S
# 50         Airport West   2/62 Clydesdale Rd      2    u  530000.0      S
# 54         Airport West      145a Victory Rd      2    u  440000.0      S
# ...                 ...                  ...    ...  ...       ...    ...
# 13129    Brunswick East       2/162 Lygon St      2    u  522000.0     SP
# 13179        Flemington  2/121 Wellington St      2    u  452500.0      S
# 13439     Greensborough      2/5 McDowell St      2    u  540000.0      S
# 13453  Hoppers Crossing      3/14 Moffatt Cr      2    u  315000.0      S
# 13495      Moonee Ponds      1/53 Buckley St      2    u  435000.0      S
#
#        SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 23     Collins  18/06/2016       2.5    3067.0  ...       1.0  1.0       0.0
# 44       Barry   4/03/2017      13.5    3042.0  ...       1.0  1.0     168.0
# 49       Barry   7/11/2016      13.5    3042.0  ...       1.0  1.0     141.0
# 50      Nelson  10/09/2016      13.5    3042.0  ...       1.0  1.0     120.0
# 54       Barry  13/08/2016      13.5    3042.0  ...       1.0  1.0     192.0
# ...        ...         ...       ...       ...  ...       ...  ...       ...
# 13129   Jellis  23/09/2017       4.0    3057.0  ...       1.0  1.0     186.0
# 13179   Nelson  23/09/2017       3.4    3031.0  ...       1.0  1.0     807.0
# 13439   Darren  26/08/2017      16.1    3088.0  ...       1.0  1.0     208.0
# 13453  Triwest  26/08/2017      18.4    3029.0  ...       1.0  1.0     150.0
# 13495   Nelson  26/08/2017       6.2    3039.0  ...       1.0  1.0    1475.0
#
#        BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# 23             60.0     1970.0          Yarra -37.80150   144.99720
# 44             86.0     2011.0  Moonee Valley -37.72150   144.88640
# 49             73.0     2013.0  Moonee Valley -37.72980   144.88830
# 50             94.0     2012.0  Moonee Valley -37.72340   144.87920
# 54              NaN        NaN  Moonee Valley -37.71770   144.87870
# ...             ...        ...            ...       ...         ...
# 13129           NaN        NaN            NaN -37.77315   144.97161
# 13179          54.0     1970.0            NaN -37.78300   144.93204
# 13439           NaN     1995.0            NaN -37.70791   145.09575
# 13453           NaN        NaN            NaN -37.87715   144.69863
# 13495          66.0     1970.0            NaN -37.75799   144.92354
#
#                   Regionname Propertycount
# 23     Northern Metropolitan        4019.0
# 44      Western Metropolitan        3464.0
# 49      Western Metropolitan        3464.0
# 50      Western Metropolitan        3464.0
# 54      Western Metropolitan        3464.0
# ...                      ...           ...
# 13129  Northern Metropolitan        5533.0
# 13179  Northern Metropolitan        3593.0
# 13439  Northern Metropolitan        8524.0
# 13453   Western Metropolitan       13830.0
# 13495   Western Metropolitan        6232.0
#
# [1087 rows x 21 columns]

# %%
lima_murah = df_murah.sort_values(by='Price').head(5).reset_index().drop(columns='index')
lima_murah
# Out:
#       Suburb                Address  Rooms Type     Price Method    SellerG  \
# 0     Albion          8/6 Ridley St      1    u  145000.0     PI     Biggin
# 1     Albion         5/25 Ridley St      2    u  190000.0     SP    Burnham
# 2  Reservoir    1/164 Leamington St      1    u  216000.0      S       Brad
# 3    Glenroy  14/854 Pascoe Vale Rd      2    u  230000.0     PI      Raine
# 4  Reservoir         4/1067 High St      2    u  240000.0     PI  Stockdale
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  28/05/2016      13.9    3020.0  ...       1.0  1.0      36.0           NaN
# 1  30/07/2016      13.9    3020.0  ...       1.0  1.0       0.0           NaN
# 2  24/09/2016      11.2    3073.0  ...       1.0  1.0       0.0          45.0
# 3  18/03/2017      13.0    3046.0  ...       1.0  1.0    1996.0           NaN
# 4  26/07/2016      11.2    3073.0  ...       1.0  1.0      82.0           NaN
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN     Brimbank  -37.7833    144.8266   Western Metropolitan
# 1        NaN     Brimbank  -37.7839    144.8239   Western Metropolitan
# 2     1970.0      Darebin  -37.7111    144.9919  Northern Metropolitan
# 3        NaN     Moreland  -37.7020    144.9154  Northern Metropolitan
# 4     1970.0      Darebin  -37.6983    145.0104  Northern Metropolitan
#
#   Propertycount
# 0        2185.0
# 1        2185.0
# 2       21650.0
# 3        8870.0
# 4       21650.0
#
# [5 rows x 21 columns]

# %%
a=1
for i in range(len(lima_murah)):
    for i in range(a):
        b = [lima_murah['Lattitude'][i],lima_murah['Longtitude'][i]]
        a <= 5
b
# Out:
# [-37.7833, 144.8266]

# %%
# buat peta jakarta
melbourne_map = folium.Map(location=[-37.840935, 144.946457])


for i in range (len(lima_murah)):
    murah_pin = folium.Marker(
        location= [lima_murah['Lattitude'][i],lima_murah['Longtitude'][i]],
        tooltip= int(lima_murah['Price'][i]),                                         # label ketika dihover
        popup= df['Suburb'][i] + ' ' + df['Address'][i],                        # label ketika diklik
        icon= folium.Icon( 
            color='green',
            icon='usd'
        )
    )
    murah_pin.add_to(melbourne_map)
        
maksimal_pin.add_to(melbourne_map)
melbourne_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f77eaf7c5b49a7057fd1748a0f03fb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f77eaf7c5b49a7057fd1748a0f03fb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f77eaf7c5b49a7057fd1748a0f03fb4 = L.map(
#                 &quot;map_0f77eaf7c5b49a7057fd1748a0f03fb4&quot;,
#                 {
#                     center: [-37.840935, 144.946457],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0d06f0b0d6552e126e7f1fb40b0fbe4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f77eaf7c5b49a7057fd1748a0f03fb4);
#
#
#             var marker_57f82fafdc31df4185de50434233e927 = L.marker(
#                 [-37.7833, 144.8266],
#                 {}
#             ).addTo(map_0f77eaf7c5b49a7057fd1748a0f03fb4);
#
#
#             var icon_f784427d01f3b26041928c0408842f66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;usd&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_57f82fafdc31df4185de50434233e927.setIcon(icon_f784427d01f3b26041928c0408842f66);
#
#
#         var popup_534c9c614824cab4ee6df7241070f336 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6d03357962a4b6365b5fb65120b6af6 = $(`&lt;div id=&quot;html_a6d03357962a4b6365b5fb65120b6af6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbotsford 85 Turner St&lt;/div&gt;`)[0];
#                 popup_534c9c614824cab4ee6df7241070f336.setContent(html_a6d03357962a4b6365b5fb65120b6af6);
#
#
#
#         marker_57f82fafdc31df4185de50434233e927.bindPopup(popup_534c9c614824cab4ee6df7241070f336)
#         ;
#
#
#
#
#             marker_57f82fafdc31df4185de50434233e927.bindTooltip(
#                 `&lt;div&gt;
#                      145000
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_482557a2337d15593149e2a0077da616 = L.marker(
#                 [-37.7839, 144.8239],
#                 {}
#             ).addTo(map_0f77eaf7c5b49a7057fd1748a0f03fb4);
#
#
#             var icon_3054c1cb02215d51233f02130ec93c32 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;usd&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_482557a2337d15593149e2a0077da616.setIcon(icon_3054c1cb02215d51233f02130ec93c32);
#
#
#         var popup_5c1c3ab959728bf1fd15515b84444dcb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7fd4884eaebfe94d55c341f24c4fc0ff = $(`&lt;div id=&quot;html_7fd4884eaebfe94d55c341f24c4fc0ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbotsford 25 Bloomburg St&lt;/div&gt;`)[0];
#                 popup_5c1c3ab959728bf1fd15515b84444dcb.setContent(html_7fd4884eaebfe94d55c341f24c4fc0ff);
#
#
#
#         marker_482557a2337d15593149e2a0077da616.bindPopup(popup_5c1c3ab959728bf1fd15515b84444dcb)
#         ;
#
#
#
#
#             marker_482557a2337d15593149e2a0077da616.bindTooltip(
#                 `&lt;div&gt;
#                      190000
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e992ef2bf8bad10daac25697b56e9bbf = L.marker(
#                 [-37.7111, 144.9919],
#                 {}
#             ).addTo(map_0f77eaf7c5b49a7057fd1748a0f03fb4);
#
#
#             var icon_983c32d3c0316d1fe836a27f42fedf2b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;usd&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e992ef2bf8bad10daac25697b56e9bbf.setIcon(icon_983c32d3c0316d1fe836a27f42fedf2b);
#
#
#         var popup_e399071ad9582f91246d6fd15e8885a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9827ca057f14ac2f1c4474c285012a9d = $(`&lt;div id=&quot;html_9827ca057f14ac2f1c4474c285012a9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbotsford 5 Charles St&lt;/div&gt;`)[0];
#                 popup_e399071ad9582f91246d6fd15e8885a9.setContent(html_9827ca057f14ac2f1c4474c285012a9d);
#
#
#
#         marker_e992ef2bf8bad10daac2
